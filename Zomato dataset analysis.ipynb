# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
## read dataset
df1=pd.read_csv("C:\\Users\\Lucifer\\panda\\datasets\\data sets\\zomato.csv")
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.head().iloc[:,9:]
# Out:
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
# 3                   Japanese, Sushi                  1500  Botswana Pula(P)
# 4                  Japanese, Korean                  1500  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  \
# 0               Yes                  No                No
# 1               Yes                  No                No
# 2               Yes                  No                No
# 3                No                  No                No
# 4               Yes                  No                No
#
#   Switch to order menu  Price range  Aggregate rating Rating color  \
# 0                   No            3               4.8   Dark Green
# ...

# %%
df1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df2=pd.read_excel("C:\\Users\\Lucifer\\panda\\datasets\\data sets\\Zomato_Country-Code.xlsx")
df2.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
df1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Country Code    0
# Country         0
# dtype: int64

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df2.shape
# Out:
# (15, 2)

# %%
df1["Country Code"].unique()
# Out:
# array([162,  30, 216,  14,  37, 184, 214,   1,  94, 148, 215, 166, 189,
#        191, 208], dtype=int64)

# %%
df2["Country Code"].unique()
# Out:
# array([  1,  14,  30,  37,  94, 148, 162, 166, 184, 189, 191, 208, 214,
#        215, 216], dtype=int64)

# %%
## to merge the two dataframe in one
df=pd.merge(df1,df2,on="Country Code",how="left")
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# Restaurant ID           0.000000
# Restaurant Name         0.000000
# Country Code            0.000000
# City                    0.000000
# Address                 0.000000
# Locality                0.000000
# Locality Verbose        0.000000
# Longitude               0.000000
# Latitude                0.000000
# Cuisines                0.094231
# Average Cost for two    0.000000
# Currency                0.000000
# Has Table booking       0.000000
# Has Online delivery     0.000000
# Is delivering now       0.000000
# Switch to order menu    0.000000
# Price range             0.000000
# Aggregate rating        0.000000
# Rating color            0.000000
# Rating text             0.000000
# Votes                   0.000000
# Country                 0.000000
# dtype: float64

# %%
df["Cuisines"].dtypes
# Out:
# dtype('O')

# %%
df["Cuisines"].fillna(df["Cuisines"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.columns:
    print(i,"----",df[i].unique())
# Out:
# Restaurant ID ---- [6317637 6304287 6300002 ... 5915807 5916112 5927402]
# Restaurant Name ---- ['Le Petit Souffle' 'Izakaya Kikufuji' 'Heat - Edsa Shangri-La' ...
#  'Huqqa' 'A\x81ô\x81ôk Kahve' "Walter's Coffee Roastery"]
# Country Code ---- [162  30 216  14  37 184 214   1  94 148 215 166 189 191 208]
# City ---- ['Makati City' 'Mandaluyong City' 'Pasay City' 'Pasig City' 'Quezon City'
#  'San Juan City' 'Santa Rosa' 'Tagaytay City' 'Taguig City' 'Brasí_lia'
#  'Rio de Janeiro' 'Sí£o Paulo' 'Albany' 'Armidale' 'Athens' 'Augusta'
#  'Balingup' 'Beechworth' 'Boise' 'Cedar Rapids/Iowa City' 'Chatham-Kent'
#  'Clatskanie' 'Cochrane' 'Columbus' 'Consort' 'Dalton' 'Davenport'
#  'Des Moines' 'Dicky Beach' 'Dubuque' 'East Ballina' 'Fernley' 'Flaxton'
#  'Forrest' 'Gainesville' 'Hepburn Springs' 'Huskisson' 'Inverloch'
#  'Lakes Entrance' 'Lakeview' 'Lincoln' 'Lorn' 'Macedon' 'Macon' 'Mayfield'
#  'Mc Millan' 'Middleton Beach' 'Miller' 'Monroe' 'Montville'
# ...

# %%
## task 1 avg the 0

# %%
## drop the irrelevant column
df.drop(columns="Switch to order menu",inplace=True)

# %%
df.head().iloc[:,9:]
# Out:
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
# 3                   Japanese, Sushi                  1500  Botswana Pula(P)
# 4                  Japanese, Korean                  1500  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  Price range  \
# 0               Yes                  No                No            3
# 1               Yes                  No                No            3
# 2               Yes                  No                No            4
# 3                No                  No                No            4
# 4               Yes                  No                No            4
#
#    Aggregate rating Rating color Rating text  Votes      Country
# ...

# %%
df.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000      0.148471  -0.226081 -0.052081
# Country Code               0.148471      1.000000  -0.698299  0.019792
# Longitude                 -0.226081     -0.698299   1.000000  0.043207
# Latitude                  -0.052081      0.019792   0.043207  1.000000
# Average Cost for two      -0.001693      0.043225   0.045891 -0.111088
# Price range               -0.134540      0.243327  -0.078939 -0.166688
# Aggregate rating          -0.326212      0.282189  -0.116818  0.000516
# Votes                     -0.147023      0.154530  -0.085101 -0.022962
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                    -0.001693    -0.134540         -0.326212
# Country Code                      0.043225     0.243327          0.282189
# Longitude                         0.045891    -0.078939         -0.116818
# ...

# %%
df.describe().T
# Out:
#                        count          mean           std         min  \
# Restaurant ID         9551.0  9.051128e+06  8.791521e+06   53.000000
# Country Code          9551.0  1.836562e+01  5.675055e+01    1.000000
# Longitude             9551.0  6.412657e+01  4.146706e+01 -157.948486
# Latitude              9551.0  2.585438e+01  1.100794e+01  -41.330428
# Average Cost for two  9551.0  1.199211e+03  1.612118e+04    0.000000
# Price range           9551.0  1.804837e+00  9.056088e-01    1.000000
# Aggregate rating      9551.0  2.666370e+00  1.516378e+00    0.000000
# Votes                 9551.0  1.569097e+02  4.301691e+02    0.000000
#
#                                 25%           50%           75%           max
# Restaurant ID         301962.500000  6.004089e+06  1.835229e+07  1.850065e+07
# Country Code               1.000000  1.000000e+00  1.000000e+00  2.160000e+02
# Longitude                 77.081343  7.719196e+01  7.728201e+01  1.748321e+02
# ...

# %%
## to fill the cuisins 0 value
df[df["Country"]=="United States"].iloc[:,10:]
# Out:
#      Average Cost for two   Currency Has Table booking Has Online delivery  \
# 82                     25  Dollar($)                No                  No
# 83                     10  Dollar($)                No                  No
# 84                      0  Dollar($)                No                  No
# 85                      0  Dollar($)                No                  No
# 86                     10  Dollar($)                No                  No
# ..                    ...        ...               ...                 ...
# 558                    10  Dollar($)                No                  No
# 559                    10  Dollar($)                No                  No
# 560                    25  Dollar($)                No                  No
# 561                    25  Dollar($)                No                  No
# 562                    25  Dollar($)                No                  No
#
# ...

# %%
df[df["Average Cost for two"]==0].iloc[:,10:]
# Out:
#       Average Cost for two            Currency Has Table booking  \
# 84                       0           Dollar($)                No
# 85                       0           Dollar($)                No
# 87                       0           Dollar($)                No
# 201                      0           Dollar($)                No
# 240                      0           Dollar($)                No
# 277                      0           Dollar($)                No
# 346                      0           Dollar($)                No
# 397                      0           Dollar($)                No
# 407                      0           Dollar($)                No
# 634                      0  Indian Rupees(Rs.)                No
# 637                      0  Indian Rupees(Rs.)                No
# 639                      0  Indian Rupees(Rs.)                No
# 677                      0  Indian Rupees(Rs.)                No
# ...

# %%
us_mean=df[df["Country"]=="United States"].iloc[:,10:]["Average Cost for two"].mean()
us_mean
# Out:
# 26.152073732718893

# %%
l=[84,85,87,201,240,277,346,397,407]
for i in l:
    df["Average Cost for two"].iloc[i]=us_mean
# Out:
# C:\Users\Lucifer\AppData\Local\Temp\ipykernel_2644\251717911.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Average Cost for two"].iloc[i]=us_mean

# %%
ind_mean=df[df["Country"]=="India"].iloc[:,10:]["Average Cost for two"].mean()
ind_mean
# Out:
# 624.0187624677545

# %%
l=[634,637,639,677,851,2364,2368,9242,9254]
for i in l:
    df["Average Cost for two"].iloc[i]=ind_mean
# Out:
# C:\Users\Lucifer\AppData\Local\Temp\ipykernel_2644\2673867134.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Average Cost for two"].iloc[i]=ind_mean

# %%
df[df["Average Cost for two"]==0].iloc[:,10:]
# Out:
# Empty DataFrame
# Columns: [Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []

# %%
## first we chck how many zomato resturant in each country
df["Country"].value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %%
sns.countplot(x="Country",data=df)
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
## which country do have online delivery option
df.groupby(["Country","Has Online delivery"]).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %%
## there are so many resturant in india so we find the best restursnt in india and lso dishs and we analysis in india
finaldf=df[df["Country"]=="India"]
finaldf
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
finaldf.shape
# Out:
# (8652, 21)

# %%
## most resturant in which city
k=finaldf["City"].value_counts().reset_index()
k
# Out:
#            index  City
# 0      New Delhi  5473
# 1        Gurgaon  1118
# 2          Noida  1080
# 3      Faridabad   251
# 4      Ghaziabad    25
# 5      Ahmedabad    21
# 6       Guwahati    21
# 7        Lucknow    21
# 8   Bhubaneshwar    21
# 9       Amritsar    21
# 10          Pune    20
# 11    Puducherry    20
# 12         Patna    20
# 13      Ludhiana    20
# 14        Ranchi    20
# 15         Surat    20
# 16      Vadodara    20
# 17        Nashik    20
# 18        Nagpur    20
# 19        Mysore    20
# 20        Mumbai    20
# 21      Varanasi    20
# 22     Mangalore    20
# 23          Agra    20
# 24         Kochi    20
# 25       Kolkata    20
# 26      Dehradun    20
# 27     Allahabad    20
# 28    Aurangabad    20
# 29     Bangalore    20
# 30        Bhopal    20
# 31       Chennai    20
# 32    Coimbatore    20
# 33           Goa    20
# 34        Indore    20
# 35        Jaipur    20
# 36        Kanpur    20
# 37         Vizag    20
# 38    Chandigarh    18
# ...

# %%
sns.barplot(x=k["index"],y=k["City"],data=df);

# %%
plt.pie(k["City"].value_counts().values,labels=k["City"].value_counts().index,autopct="%0.02f%%");

# %%
k["index"].iloc[5:43]=k["index"].iloc[5:43].apply(lambda x:"others")
k
# Out:
# C:\Users\Lucifer\AppData\Local\Temp\ipykernel_2644\4174955765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   k["index"].iloc[5:43]=k["index"].iloc[5:43].apply(lambda x:"others")
#         index  City
# 0   New Delhi  5473
# 1     Gurgaon  1118
# 2       Noida  1080
# 3   Faridabad   251
# 4   Ghaziabad    25
# 5      others    21
# 6      others    21
# 7      others    21
# 8      others    21
# 9      others    21
# 10     others    20
# 11     others    20
# 12     others    20
# 13     others    20
# 14     others    20
# 15     others    20
# 16     others    20
# 17     others    20
# 18     others    20
# 19     others    20
# 20     others    20
# 21     others    20
# 22     others    20
# 23     others    20
# 24     others    20
# 25     others    20
# 26     others    20
# ...

# %%
k1=k.groupby(["index"])["City"].sum().reset_index()
k1
# Out:
#        index  City
# 0  Faridabad   251
# 1  Ghaziabad    25
# 2    Gurgaon  1118
# 3  New Delhi  5473
# 4      Noida  1080
# 5     others   705

# %%
plt.pie(k1["City"],explode=[1,2,0,0,0,0],labels=k1["index"],autopct="%0.02f%%");

# %%
## which is the hot selling cuisines
finaldf["Cuisines"].value_counts()
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Fast Food                                                348
# Chinese                                                  340
# North Indian, Mughlai                                    334
#                                                         ...
# Chinese, Japanese, Thai, Malaysian, Vietnamese, Asian      1
# North Indian, Street Food, Mughlai                         1
# Seafood, South Indian, Andhra, Hyderabadi, Goan            1
# Chinese, Fast Food, North Indian, South Indian             1
# American, North Indian, Thai, Continental                  1
# Name: Cuisines, Length: 1392, dtype: int64

# %%
## which resturant is expensive based on cuisines on each city
finaldf["Average Cost for two"].unique()
# Out:
# array([ 850.        ,  700.        ,  500.        ,  400.        ,
#        1000.        , 2000.        , 2500.        ,  800.        ,
#        3600.        ,  624.01876247,  550.        , 1100.        ,
#        1500.        ,  900.        , 1800.        ,  300.        ,
#        1400.        ,  350.        ,  450.        ,  600.        ,
#         950.        , 1200.        ,  200.        ,  100.        ,
#         150.        ,  650.        , 1300.        , 2400.        ,
#         250.        , 1600.        , 2200.        ,  750.        ,
#        1700.        , 1250.        , 1900.        , 2700.        ,
#        3500.        , 5000.        , 2300.        , 1750.        ,
#        3200.        , 3000.        , 2100.        , 1850.        ,
#        4500.        , 4000.        , 3300.        ,  120.        ,
#        1350.        , 1650.        , 1950.        , 1050.        ,
#         290.        ,   50.        , 1450.        , 2800.        ,
# ...

# %%
k=finaldf.groupby(["City","Cuisines"])["Average Cost for two"].mean().reset_index().sort_values(by=["City","Average Cost for two"])
k.head(16)
# Out:
#          City                                           Cuisines  \
# 12       Agra                                         Rajasthani
# 5        Agra                                       North Indian
# 14       Agra                             South Indian, Desserts
# 0        Agra  Cafe, Italian, Mexican, North Indian, Continental
# 1        Agra                        Cafe, North Indian, Chinese
# 3        Agra                                     Italian, Pizza
# 10       Agra                            North Indian, Fast Food
# 13       Agra                      Rajasthani, Gujarati, Mughlai
# 2        Agra        Chinese, Italian, Continental, North Indian
# 8        Agra                     North Indian, Chinese, Mughlai
# 6        Agra                 North Indian, Chinese, Continental
# 7        Agra        North Indian, Chinese, Continental, Mughlai
# 11       Agra                              North Indian, Mughlai
# ...

# %%
## how many resturant of each cuisines in each city
finaldf.groupby(["City"])["Cuisines"].value_counts()
# Out:
# City   Cuisines
# Agra   North Indian, Mughlai                                        5
#        North Indian, Chinese, Continental                           2
#        Cafe, Italian, Mexican, North Indian, Continental            1
#        Cafe, North Indian, Chinese                                  1
#        Chinese, Italian, Continental, North Indian                  1
#                                                                    ..
# Vizag  Mughlai, Chinese, Cafe, BBQ, Cajun                           1
#        North Indian, Biryani                                        1
#        North Indian, Chinese, Mediterranean                         1
#        South Indian, Chinese, Continental, Italian, North Indian    1
#        South Indian, North Indian                                   1
# Name: Cuisines, Length: 2220, dtype: int64

# %%
## which cuisin type resturatnt has highest and lowest rating in each city
x=finaldf.groupby(["City","Cuisines"])["Aggregate rating"].agg(["mean"]).reset_index().sort_values(by=["City","mean"])
x.head(15)
# Out:
#     City                                           Cuisines  mean
# 7   Agra        North Indian, Chinese, Continental, Mughlai  3.40
# 5   Agra                                       North Indian  3.60
# 13  Agra                      Rajasthani, Gujarati, Mughlai  3.60
# 11  Agra                              North Indian, Mughlai  3.84
# 6   Agra                 North Indian, Chinese, Continental  3.85
# 0   Agra  Cafe, Italian, Mexican, North Indian, Continental  3.90
# 4   Agra                                            Mughlai  4.00
# 9   Agra                             North Indian, European  4.00
# 12  Agra                                         Rajasthani  4.00
# 10  Agra                            North Indian, Fast Food  4.10
# 14  Agra                             South Indian, Desserts  4.10
# 2   Agra        Chinese, Italian, Continental, North Indian  4.20
# 8   Agra                     North Indian, Chinese, Mughlai  4.20
# ...

# %%
## what is the max,min, avg resturant in india
finaldf["Aggregate rating"].agg(["mean","max","min"])
# Out:
# mean    2.523324
# max     4.900000
# min     0.000000
# Name: Aggregate rating, dtype: float64

# %%
## check rating of zomato order/service
rating=finaldf.groupby(["Aggregate rating","Rating color","Rating text"]).size().reset_index().rename(columns={0:"Rating count"})
rating
# Out:
#     Aggregate rating Rating color Rating text  Rating count
# 0                0.0        White   Not rated          2139
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            26
# 6                2.3          Red        Poor            46
# 7                2.4          Red        Poor            83
# 8                2.5       Orange     Average           109
# 9                2.6       Orange     Average           190
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           314
# 12               2.9       Orange     Average           380
# 13               3.0       Orange     Average           465
# 14               3.1       Orange     Average           511
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="Aggregate rating",y="Rating count",hue="Rating text",data=rating,palette=["black","red","orange","green","green"]);

# %%
## which resturant are more rated of each city
y=finaldf.groupby(["City","Restaurant Name","Aggregate rating"])["Votes"].agg(["mean"]).reset_index()
y.rename(columns={"mean":"votes"},inplace=True)

# %%
y.sort_values(by=["Aggregate rating","votes"],ascending=False)
# Out:
#            City            Restaurant Name  Aggregate rating   votes
# 1727    Kolkata            Barbeque Nation               4.9  3859.5
# 1812     Mumbai            Mirchi And Mime               4.9  3244.0
# 1627  Hyderabad  AB's - Absolute Barbecues               4.9  2817.0
# 4918  New Delhi         Naturals Ice Cream               4.9  2620.0
# 4007  New Delhi  Indian Accent - The Manor               4.9  1934.0
# ...         ...                        ...               ...     ...
# 7905      Noida   Vivino - Hotel Golf View               0.0     0.0
# 7907      Noida                  WOW Zaika               0.0     0.0
# 7918      Noida               Whatslife.in               0.0     0.0
# 7925      Noida                 Wow Noodle               0.0     0.0
# 7932      Noida                       Yeoh               0.0     0.0
#
# [8115 rows x 4 columns]

# %%
## finding the best resturant in new delhi
y[y["City"]=="New Delhi"].sort_values(by="Aggregate rating",ascending=False)
# Out:
#            City            Restaurant Name  Aggregate rating   votes
# 4007  New Delhi  Indian Accent - The Manor               4.9  1934.0
# 4626  New Delhi             Masala Library               4.9   408.0
# 4918  New Delhi         Naturals Ice Cream               4.9  2620.0
# 4333  New Delhi               Kopper Kadai               4.8    83.0
# 4519  New Delhi                MOB Brewpub               4.7    52.0
# ...         ...                        ...               ...     ...
# 3520  New Delhi              Food En Vouge               0.0     0.0
# 3519  New Delhi                 Food Daddy               0.0     1.0
# 6028  New Delhi            Sonu Bhojanalya               0.0     2.0
# 6027  New Delhi            Soni Food Court               0.0     0.0
# 1884  New Delhi               #InstaFreeze               0.0     2.0
#
# [5042 rows x 4 columns]

# %%
## following details of most rated resturant in new delhi simmilarly we can find for other city
finaldf[(finaldf["City"]=="New Delhi") & (finaldf["Aggregate rating"]==4.9)][["Restaurant Name","Locality","Cuisines","Has Online delivery","Has Table booking","Votes","Average Cost for two","Rating color","Rating text"]]
# Out:
#                 Restaurant Name         Locality       Cuisines  \
# 3013         Naturals Ice Cream  Connaught Place      Ice Cream
# 3601  Indian Accent - The Manor   Friends Colony  Modern Indian
# 4298             Masala Library          Janpath  Modern Indian
#
#      Has Online delivery Has Table booking  Votes  Average Cost for two  \
# 3013                 Yes                No   2620                 150.0
# 3601                  No                No   1934                4000.0
# 4298                  No                No    408                5000.0
#
#      Rating color Rating text
# 3013   Dark Green   Excellent
# 3601   Dark Green   Excellent
# 4298   Dark Green   Excellent

# %%
## HOW MANY not rated restutants in each city
z=finaldf[finaldf["Aggregate rating"]==0.0]
z.groupby(["City"])["Rating text"].value_counts()
# Out:
# City       Rating text
# Faridabad  Not rated       100
# Ghaziabad  Not rated         2
# Gurgaon    Not rated       228
# New Delhi  Not rated      1425
# Noida      Not rated       384
# Name: Rating text, dtype: int64

# %%
## how many rsturatnt offer online delivery,prior table booking to their customer
print("the number of restaurants which gives online delivery  and proir table booking option----",len(finaldf[(finaldf["Has Online delivery"]=="Yes") & (finaldf["Has Table booking"]=="Yes")]))
print("the number of restaurants which gives only online delivery  and no proir table booking option----",len(finaldf[(finaldf["Has Online delivery"]=="Yes") & (finaldf["Has Table booking"]=="No")]))
print("the number of restaurants which gives only proir table booking option and no online delievery----",len(finaldf[(finaldf["Has Online delivery"]=="No") & (finaldf["Has Table booking"]=="Yes")]))
print("the number of restaurants which gives neither option ----",len(finaldf[(finaldf["Has Online delivery"]=="No") & (finaldf["Has Table booking"]=="No")]))
# Out:
# the number of restaurants which gives online delivery  and proir table booking option---- 427
# the number of restaurants which gives only online delivery  and no proir table booking option---- 1996
# the number of restaurants which gives only proir table booking option and no online delievery---- 684
# the number of restaurants which gives neither option ---- 5545
